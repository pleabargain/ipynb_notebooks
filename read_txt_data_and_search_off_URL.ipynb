# %% [markdown]
# <a href="https://colab.research.google.com/github/pleabargain/ipynb_notebooks/blob/master/read_txt_data_and_search_off_URL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request
fp = urllib.request.urlopen("http://www8.cs.umu.se/kurser/TDBD15/VT07/datafile1.txt")#simple text file
mybytes = fp.read()
# note that Python3 does not read the html code as string
# but as html code bytearray, convert to string with
mystr = mybytes.decode("utf8")
fp.close()




print(mystr)
# Out:
#  Product with id 1 is Jeans
#  Product with id 2 is Socks
#  Product with id 3 is Sweater
#  Product with id 4 is Skirt
#  Product with id 5 is Gloves
#  Product with id 6 is Belt
#  Product with id 7 is Purse
#  Product with id 8 is Candy
#  Product with id 9 is Phone
#  Product with id 10 is Batteries
#  Product with id 11 is Game
#  Product with id 12 is Notebook
#  Product with id 13 is Scale
#  Product with id 14 is Tent
#  Product with id 15 is Iron
#  Product with id 16 is Candles
#  Product with id 17 is Shoes
#  Product with id 18 is Tie
#  Product with id 19 is Pen
#  Product with id 20 is Ladder
#  Product with id 21 is Radios
#  Product with id 22 is TV
#
#  Customer 1 has first name I., last name Pedersson, age 40, gender Male
#  Customer 1 has Gloves on their shopping list
#  Customer 1 has Belt on their shopping list
#  Customer 1 initial position (15 79)
#  Customer 2 has first name D., last name Pedersson, age 28, gender Female
# ...
